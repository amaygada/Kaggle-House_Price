# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')
df = pd.concat([df_test ,df_train] , axis=0)
df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
def boxPlots(var):
    data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
    f, ax = plt.subplots(figsize=(8, 6))
    fig = sns.boxplot(x=var, y="SalePrice", data=data)
    fig.axis(ymin=0, ymax=  755000);

# %%
def scatterPlots(var):
    f,ax = plt.subplots()
    plt.scatter(df[var] , df['SalePrice'])
    plt.xlabel = var
    plt.ylabel = 'SalePrice'
    ax.set(xlabel=var , ylabel='SalePrice')
    plt.show()

# %% [markdown]
# # Categorical Corelation

# %% [markdown]
# Stret vs Alley
#
# LotShape vs LandContour

# %% [markdown]
# # Feature Examination

# %% [markdown]
# 1. bsmtSF1 + SF2 + unfinished = totalSF
#
#    therefore removing bsmtFinSF1 and bsmtFinSF2
#
#
# 2. HouseStyle=='1story'
#
#     then fill na of 2ndFlrSF as 0

# %% [markdown]
# ### MSSubClass

# %%
boxPlots('MSSubClass')

# %% [markdown]
# weird non linear relationship with SP

# %% [markdown]
# ### MSZoning

# %%
boxPlots('MSZoning')

# %% [markdown]
# non linear relation with SalePrice

# %% [markdown]
# ### LotFrontage

# %%
scatterPlots('LotFrontage')

# %% [markdown]
# A linear relationship with SalePrice
#
# Contains Outliers at x>300

# %% [markdown]
# ### LotArea

# %%
scatterPlots('LotArea')

# %% [markdown]
# has a pretty steep linear relationship with SalePrice
#
# x>150000 can be considered as outliers

# %% [markdown]
# ### Street

# %%
boxPlots('Street')

# %% [markdown]
# Pave has average higher preference

# %% [markdown]
# ### Alley

# %%
boxPlots('Alley')

# %% [markdown]
# Alley might be corelated with Street

# %% [markdown]
# ### LotShape

# %%
boxPlots('LotShape')

# %% [markdown]
# seems to have a slight linear relationshhip with SalePrice

# %% [markdown]
# ### LandContour

# %%
boxPlots('LandContour')

# %% [markdown]
# Since categorical properties may not have their x in sequence like eg year,etc ,We will not really see much of a relationship and henced I will only draw the box plot

# %% [markdown]
# ### LandSlope

# %%
boxPlots('LandSlope')

# %% [markdown]
# Might be highly corelated with the LandContour

# %% [markdown]
# ### OverallQual

# %%
boxPlots('OverallQual')

# %% [markdown]
# Since the x here is sequential we can predict a relationship
#
# and we see there is quite a linear possibility of fitting this data

# %% [markdown]
# ### OverallCond

# %%
boxPlots('OverallCond')

# %% [markdown]
# ### YearBuilt

# %%
boxPlots('YearBuilt')

# %% [markdown]
# again x is sequential
#
# very old houses have high price
#
# But then newer houses getter better price so almost linear with a slight non linearity with earlier years

# %% [markdown]
# ### MasVnrArea

# %%
scatterPlots('MasVnrArea')

# %% [markdown]
# ### BsmtFinSF1

# %%
scatterPlots('BsmtFinSF1')

# %% [markdown]
# ### BsmtFinSF2

# %%
scatterPlots('BsmtFinSF2')

# %% [markdown]
# ### 1stFlrSF and 2ndFlrSF

# %%
scatterPlots('1stFlrSF')

# %%
scatterPlots('2ndFlrSF')

# %% [markdown]
# ### LowQualFinSF

# %%
scatterPlots('LowQualFinSF')

# %% [markdown]
# ### GrLivArea|

# %%
scatterPlots('GrLivArea')

# %% [markdown]
# ### Bedroom

# %%
boxPlots('YrSold')

# %%
scatterPlots('MiscVal')
